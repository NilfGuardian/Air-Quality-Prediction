# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('../data/raw/city_day.csv')

# Display the first few rows
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Summary statistics
print(data.describe())

# Visualize AQI distribution
sns.histplot(data['AQI'].dropna(), kde=True)
plt.title('AQI Distribution')
plt.show()
# Out:
#         City        Date  PM2.5  PM10  NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN NaN  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN NaN  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN NaN  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN NaN  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN NaN  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN
# City              0
# Date              0
# PM2.5          4255
# PM10          10702
# NO             4509
# NO2            3159
# NOx            4021
# NH3            9785
# CO             1999
# SO2            3499
# O3             3510
# Benzene        5122
# Toluene        7409
# Xylene        16417
# AQI            4251
# AQI_Bucket     4251
# dtype: int64
#               PM2.5          PM10            NO           NO2           NOx  \
# count  21300.000000  14853.000000  21046.000000  22396.000000  21534.000000
# mean      72.824121    127.653183     17.658008     29.481695     33.835887
# std       67.356092     94.974574     22.539144     25.278898     32.688813
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       32.157500     62.340000      5.900000     12.197500     13.422500
# 50%       53.090000    102.770000      9.950000     22.340000     24.570000
# 75%       87.210000    161.180000     19.717500     38.430000     42.167500
# max      949.990000   1000.000000    351.300000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  15770.000000  23556.000000  22056.000000  22045.000000  20433.000000
# mean      25.667720      2.466555     15.097498     34.430208      3.324202
# std       27.379991      7.499295     19.299535     21.411852     16.887308
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        9.342500      0.530000      5.570000     19.010000      0.130000
# 50%       18.185000      0.930000      9.120000     30.880000      0.980000
# 75%       33.050000      1.520000     15.610000     45.430000      2.850000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene       Xylene           AQI
# count  18146.000000  9138.000000  21304.000000
# mean       9.148687     3.224390    177.582473
# std       21.316590     6.726918    147.398293
# min        0.000000     0.000000     13.000000
# 25%        0.730000     0.120000     85.000000
# 50%        2.930000     0.840000    126.000000
# 75%        8.987500     3.370000    230.000000
# max      454.850000   170.370000   2049.000000
